# %%
import sys
import sys
from PyQt5.QtWidgets import (QApplication, QWidget, QPushButton, 
                             QGridLayout, QLabel,QHBoxLayout,
                            QMainWindow)

def main():
    app = QApplication(sys.argv)
    main_window = QMainWindow()
    hello_button = QPushButton("Hello world")
    
    hello_button.clicked.connect(on_click)
    main_window.setCentralWidget(hello_button)
    main_window.show()
    app.exec_()
    
def on_click():
    print ("Hello World")

if __name__ == '__main__':
    main()

# %%
import sys
from PyQt5.QtWidgets import (QApplication, QWidget, QPushButton, 
                             QGridLayout, QMainWindow, QVBoxLayout,
                            )


class ButtonBoxWigdet(QWidget):
    def __init__(self, parent=None):
        QWidget.__init__(self, parent=parent)
        self.setup_ui()
    def setup_ui(self):
        self.start_button = QPushButton("START", parent=self)
        self.stop_button = QPushButton("STOP", parent=self)
        self.reset_button = QPushButton("RESET", parent=self)
        self.quit_button = QPushButton("QUIT", parent=self)
        
        layout = QGridLayout()
        layout.addWidget(self.start_button, 0, 0)
        layout.addWidget(self.stop_button, 0, 1)
        layout.addWidget(self.reset_button, 1, 0)
        layout.addWidget(self.quit_button, 1, 1)
        
        self.setLayout(layout)
def main():
    #おまじない
    app = QApplication(sys.argv)
    #レイアウト用のインスタンス
    panel = QWidget()
    
    #ボタンウィジェットをインスタンスにした
    button_box_widget = ButtonBoxWigdet(parent=panel)
    
    #vertical(垂直方向)にウィジェットを足し算できる関数
    panel_layout = QVBoxLayout()
    #ボタンウィジェットを追加
    panel_layout.addWidget(button_box_widget)
    
    #ウィジェットのレイアウト情報をpanelに入れた
    panel.setLayout(panel_layout)
    panel.setFixedSize(320, 200)
    
    #メインウィンドウ作成
    main_window = QMainWindow()
    main_window.setWindowTitle("Ramen Timer")
    
    #panelをmain_windowの中心に置く
    main_window.setCentralWidget(panel)
    main_window.show()
    app.exec_()
    
if __name__ == '__main__':
    main()

# %%
import sys
from PyQt5.QtWidgets import (QApplication, QWidget, QPushButton, 
                             QGridLayout, QMainWindow, QVBoxLayout,
                            )


class ButtonBoxWigdet(QWidget):
    def __init__(self, parent=None):
        QWidget.__init__(self, parent=parent)
        self.setup_ui()
    def setup_ui(self):
        self.start_button = QPushButton("START", parent=self)
        self.stop_button = QPushButton("STOP", parent=self)
        self.reset_button = QPushButton("RESET", parent=self)
        self.quit_button = QPushButton("QUIT", parent=self)
        
        layout = QGridLayout()
        layout.addWidget(self.start_button, 0, 0)
        layout.addWidget(self.stop_button, 0, 1)
        layout.addWidget(self.reset_button, 1, 0)
        layout.addWidget(self.quit_button, 1, 1)
        
        self.setLayout(layout)

class CoutDownWidget(QWidget):
    def __init__(self, parent=None):
        QWidget.__init__(self, parent=parent)
        self.interval = 10
        self.setup_ui()
    def self.setup_ui(self):
        set
        
        
def main():
    #おまじない
    app = QApplication(sys.argv)
    #レイアウト用のインスタンス
    panel = QWidget()
    
    #ボタンウィジェットをインスタンスにした
    button_box_widget = ButtonBoxWigdet(parent=panel)
    
    #vertical(垂直方向)にウィジェットを足し算できる関数
    panel_layout = QVBoxLayout()
    #ボタンウィジェットを追加
    panel_layout.addWidget(button_box_widget)
    
    #ウィジェットのレイアウト情報をpanelに入れた
    panel.setLayout(panel_layout)
    panel.setFixedSize(320, 200)
    
    #メインウィンドウ作成
    main_window = QMainWindow()
    main_window.setWindowTitle("Ramen Timer")
    
    #panelをmain_windowの中心に置く
    main_window.setCentralWidget(panel)
    main_window.show()
    app.exec_()
    
if __name__ == '__main__':
    main()
# Out:
#   File "<ipython-input-3-5d3c56488db7>", line 30
#     def self.setup_ui(self):
#             ^
# SyntaxError: invalid syntax
